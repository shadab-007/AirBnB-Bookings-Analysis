# %% [markdown]
# <a href="https://colab.research.google.com/github/shadab-007/AirBnB-Bookings-Analysis/blob/main/Capstone_Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - AirBnB Bookings Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# **Name** - SHADAB HUSSAIN ZAMIN KHAN

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Airbnb is Leading online marketplace that connect travellers with local host in over 191 countries. its offer platforms for people to book short terms accomodation rentals such as apartments houses , villas and rooms making it easier at more affordable to travel. airbbnb has become popular option for travlers because it offers a unique experience of living like a local in foreign city, rather then staying in traditional hotels.
#
# Airbnb has growing rapidly since its inceptions in 2008 in 2019 the company had 150 millions user worldwide and over 7 millions listing is available for booking. the majority of airbnb are for entire rooms and apartment but the platforms also offer private rooms and shared room in some location.
#
# Airbnb offer various type of accomodation to travellers based on their preference , budget and location. Host can set their own prices and choose the accomodation the prices they offer, as well as the services they provide to guest. this means the prices for Airbnb can varied widely such as seasonality, and demands.
#
# According to Airbnb 2021s report top 10 country for bookings are The US, France, SPain Italy, Mexico, Canada, Thailand , Australia , Germany Portugal,. The most Popular destinations within this country are also varied but they tend to be major cities for eg:- In US the New york city , los angleses and san francisco are the most popular destination. In Europe Paris, London , Barcelona are among the most popular.
#
# AirBnb has effected by covid-19 pandemic as travel restrictions and lockdown had impacted the travel industries as whole.In conclusion Airbnb has become a popular optionfor travellers world wide offering the unique and affordable way to experience different cultures and destination. Despite the covid-19 challenges Airbnb remains strong player in travel industries and expected to continue grow and evolve in the years to come.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/shadab-007/AirBnB-Bookings-Analysis

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Our main objective is to increase the satisfaction of the customer as well increase the profit of the business.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# AirBnb is a business which connects apartment and property owners with customers.we all know that Airbnb how easy this business has made travel with data that present on AirBnb server, we can make this Business even easier and convineint and also analyzing customer behaviour we can generate good revenue of the business.Customer can stay in given rented apartment during his travel or stay in that particular Location. we can find out what kind of places customer like to rome and what kinds of rooms he like to live. how many people hang out with family and how many people walk alone from this we can find out the facilities of like and also they can improve the facilities. Data analysis is nothing less than miracle through this we can provide the customers with the facilities of each choice can be even better.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df=pd.read_csv("/content/drive/MyDrive/Capstone project 1/Airbnb NYC 2019.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (48895, 16)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(df[df.duplicated()])
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(df.isnull().sum())
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Visualizing the missing values
sns.heatmap(df.isnull(),cbar=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The above Data shows only two features which has major null values are the number_of_reviews and the reviews_per_month

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
df.describe(include='all')
# Out:
#                   id            name       host_id host_name  \
# count   4.889500e+04           48879  4.889500e+04     48874
# unique           NaN           47905           NaN     11452
# top              NaN  Hillside Hotel           NaN   Michael
# freq             NaN              18           NaN       417
# mean    1.901714e+07             NaN  6.762001e+07       NaN
# std     1.098311e+07             NaN  7.861097e+07       NaN
# min     2.539000e+03             NaN  2.438000e+03       NaN
# 25%     9.471945e+06             NaN  7.822033e+06       NaN
# 50%     1.967728e+07             NaN  3.079382e+07       NaN
# 75%     2.915218e+07             NaN  1.074344e+08       NaN
# max     3.648724e+07             NaN  2.743213e+08       NaN
#
#        neighbourhood_group neighbourhood      latitude     longitude  \
# count                48895         48895  48895.000000  48895.000000
# unique                   5           221           NaN           NaN
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# id: uniue id which is provided by business for the customer
#
# name: Name of the Airbnb listing
#
# Host_id: unique id which is provided by business for host.
#
# Host_name: Name on which given listing is registered.
#
# Neighbourhood_group: neighbourhood group name where the listing is regsitered
#
# Neighbourhood: Particular neighbourhood
#
# Latitude: Latitude of given listing
#
# Longitude: longitude of given listing
#
# Room_type: type of room which is available on AirBnb
#
# Price: Price for particular listing
#
# Minimum_Nights: for how many we can rent in the given listing
#
# number_of_reviews: Number of reviews for particular listing
#
# last_review: Date of last review for particular AirBnb
#
# reviews_per_month: Average of reviews per month
#
# calculated_host_lsitings_count:NUmber of listing for given host on Airbnb
#
# Availability_365: Number of days for which AirBnb iss available for 365 days

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in df.columns.tolist():
  print("No. of unique values in",i,"is",df[i].nunique(),".")
# Out:
# No. of unique values in id is 48895 .
# No. of unique values in name is 47905 .
# No. of unique values in host_id is 37457 .
# No. of unique values in host_name is 11452 .
# No. of unique values in neighbourhood_group is 5 .
# No. of unique values in neighbourhood is 221 .
# No. of unique values in latitude is 19048 .
# No. of unique values in longitude is 14718 .
# No. of unique values in room_type is 3 .
# No. of unique values in price is 674 .
# No. of unique values in minimum_nights is 109 .
# No. of unique values in number_of_reviews is 394 .
# No. of unique values in last_review is 1764 .
# No. of unique values in reviews_per_month is 937 .
# No. of unique values in calculated_host_listings_count is 47 .
# No. of unique values in availability_365 is 366 .

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# we can remove those columns which are not important
df.drop(['name','host_id','host_name'],axis=1, inplace=True)
#here we are not droping the id because id has the unique value which si 48895

# %%
#here we are going to create dataset for which the price will be less than 100 for particular customer

df1=df[df['price']<=100]
df1.head()
# Out:
#      id neighbourhood_group       neighbourhood  latitude  longitude  \
# 3  3831            Brooklyn        Clinton Hill  40.68514  -73.95976
# 4  5022           Manhattan         East Harlem  40.79851  -73.94399
# 6  5121            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 7  5178           Manhattan      Hell's Kitchen  40.76489  -73.98493
# 8  5203           Manhattan     Upper West Side  40.80178  -73.96723
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
# 6     Private room     60              45                 49  2017-10-05
# 7     Private room     79               2                430  2019-06-24
# 8     Private room     79               2                118  2017-07-21
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# ...

# %%
#by using data we can get the room type which are available for minimum one night

df2=df[df["minimum_nights"]==1]
df2.head()
# Out:
#       id neighbourhood_group neighbourhood  latitude  longitude  \
# 0   2539            Brooklyn    Kensington  40.64749  -73.97237
# 1   2595           Manhattan       Midtown  40.75362  -73.98377
# 3   3831            Brooklyn  Clinton Hill  40.68514  -73.95976
# 9   5238           Manhattan     Chinatown  40.71344  -73.99037
# 17  7322           Manhattan       Chelsea  40.74192  -73.99501
#
#           room_type  price  minimum_nights  number_of_reviews last_review  \
# 0      Private room    149               1                  9  2018-10-19
# 1   Entire home/apt    225               1                 45  2019-05-21
# 3   Entire home/apt     89               1                270  2019-07-05
# 9   Entire home/apt    150               1                160  2019-06-09
# 17     Private room    140               1                260  2019-07-01
#
#     reviews_per_month  calculated_host_listings_count  availability_365
# ...

# %%
#by using the data we can get

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
plt.figure(figsize=(10,5))
plt.title("type of room")
sns.countplot(df.room_type,palette="muted")
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I choose this chart because I wanted to know what type sof room are most available on AirBnb

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The above chart clearly shows that whole house type rooms are available in high quantity on airbnb

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# It is good for business aspect if we provide more quantity of entire home apartment at reasonable price at which our customer can afford. we can says that chart is not showing any negative growth.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
plt.figure(figsize=(10,5))
plt.title("neighbourhood")
sns.countplot(df.neighbourhood_group,palette="muted")
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# in above chart we get data of AirBnB listings in a particular neighbourhood

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# By using the chart we can analyze to increase customer satisfaction we should have enough Airbnb in each neighborhood so that we can help our business grow with customer satisfaction.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# we can say that it is negative growth , but in the chart we get the idea that we have very less amount of Airbnb listing in some paricular neighbourhood so we can work on it.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

plt.figure(figsize=(10,5))
plt.title("Room type vs availability room in 365 Days")
sns.barplot(data=df, x='room_type',y='availability_365',palette="muted")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Above graph shows which type of room is most active between customers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# by using above chart we can say that shared rooms are available for most days in 365 days

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# I observe negative growth because in chart #1 we see shared room are in very less Quantity.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
plt.figure(figsize=(10,5))
plt.title("Room type vs Number of reviews")
sns.barplot(data=df, x='room_type',y='number_of_reviews',palette="muted")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Above graph will show which type of room is most active between the customer

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# we can see the private room is having highest amoints of reviews

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Amount of reviews shows in which room type customer are more active , by using this data we can get positive business approach

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
plt.figure(figsize=(10,5))
plt.title("Neighbourhood group vs Availability")
sns.boxplot(data=df, x='neighbourhood_group',y='availability_365', palette="muted")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Because i want to show in which neighbourhood AirBnb is available for most amount of days in entire year of 365 days.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# we can see by using this chart that is staten island Airbnb is available for most amount of days during the entire 365 days , Bronx comes on next and queens comes on third. we can find the median number of the availabe days also we can get a range of days for which the room is availABLE.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# We can see in Brooklyn is having availabilty less than 200 days and we increase the amount of Airbnb listing in brooklyn which are availabe for more number of days. we can see the negative impact

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
plt.figure(figsize=(10,5))
plt.title("Number of reviews vs price")
sns.scatterplot(data=df[df.price<5000],x='number_of_reviews',y='price',palette="muted")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# by using above graph we can understand for which price range people are more interested.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# we can see between 0 to 2000 price we have maximum amount of reviews so we can understand it people are using the Airbnb which are from 0 to 2000 price and giving the reviews for them.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# by using this graph we can understand  maximum customer are using only price range between 0 to 2000 , so we can increase the number of these type of listing and we can increase the business, Expensive listings are used by only few customers we can negotiate with their price so they can be avilable for business.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
plt.figure(figsize=(10,5))
plt.title("Room type on neighbourhood group")
sns.countplot(df.neighbourhood_group,hue=df.room_type,palette="muted")
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# choose this graph for analysis of different room type in different neighbourhood

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# as we can see from above graph distribution of room type in different neighbourhood

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# chart is creating positve impact because we have listing in each neighbourhood

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
plt.figure(figsize=(10,5))
plt.title("Rooms are availabe for one night")
sns.countplot(df2.room_type,palette="muted")
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# main objective of the chart  is to traveler wants to stay for minimum nights what type of room type can he choose

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# we can get concluision of customer wants to stay only for few nights he can choose private rooms because they are available for minimum number of night like you can take private room

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# there is no negative impact on business but we can understand that the number of apartsments and shared rooms available for the minimum nights can be increased

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization 
plt.style.use("classic")
plt.figure(figsize=(10,5))
plt.title("Neighbourhood Group vs Price for one night ")
sns.boxplot(y="price",x='neighbourhood_group', data= df2[df2.price<5000])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# dataset2 represenr the data for minimum one night say, so the reason of picking above chart:- by using above chart we can find the median price for staying minimum one night in any particular niefgbourhood.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# if  a customer want to stay for only one night in any particular neighbourhood he can get the mdeian price and also he gets the range in which most of the prices are residing for example in manhattan price is near 100 and the range is quartile of box plot which is near to 80 to 100

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# Above charts shows no negative impact, on the other hand it is more informative bynusing this chart . we ar getting a price range for staying one night in particular neighbourhood . we can use these prices and provide them to customers so he can analyse his stay.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
plt.figure(figsize=(10,5))
plt.title("room type vs price for minimum one night")
sns.boxplot(data=df2[df2.price<500],x="room_type",y="price",palette="muted")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# i want to see the price for minimum one night for particular room type

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# in above chart we used df2 which represents data set for minimum one  night now we can have price range for minimum one for particular room type

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# above chart showing a postive impact on business by using above chart we can provide a price analysis for particular customer use as example we can get aprivate room in between 60 to 90 price for minimum one night

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
title="Distribution of AirBnB in different Neighbourhood"
plt.figure(figsize=(10,5))
sns.scatterplot(df.longitude,df.latitude,hue=df.neighbourhood_group,palette="muted").set_title(title)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Because by using this graph we can understand the distribution of AirBnb listings in the neighbourhood map.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# chart is clearly showing which neighbourhood having large number of airbnb listings and which is having less.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Are there any insights that lead to negative growth? justify with specific reason.
#
# it is positive that our business is available in each neighbourhood but we can also do the analysis and we can increase the business by increasing the number of listings where we have less number of listings.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

title=' Room typr location per neighborhood group'
plt.figure(figsize=(10,5))
sns.scatterplot(df.longitude, df.latitude, hue=df.room_type,palette="muted").set_title(title)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Because above graph is showing the distribution of different room type in the neighbourhood map.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# By the analysis we can see that the private room and the entire home room apartment are distributed evenly in the map

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# graph is showing negative impact because one of our product shared room is available in very less amount, we should increase the amount of shared room product by using online business campaign or by using our business strategies.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

plt.figure(figsize=(10,5))
plt.title("Number of reviews vs. price for minimum one night")
sns.barplot(data=df2[df2.price<5000], x='neighbourhood_group',y='price',palette="muted")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Because i want to show the price analysis for minimum one night for the neighbourhood.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Above graph shows the price analysis for differnt neighbourhood for minimum one night.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# the chat is not showing any negative impact

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
corr=df.corr(method="kendall")
plt.figure(figsize=(12,7))
plt.title("Correlation between different viariables\n")
sns.heatmap(corr,annot=True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Correlation chart shows the realtion between all the variables data points

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Correlation ranges -1 to +1. Values closer to zero menas there is no linear trend between two vsriables. the close to 1 the correlation is more positively correlated they are, that is as one increases so does the other and closer to 1the stronger this relationship is in above chart each box is shwoing the correlation between two variables by analysis we can see more variables or data points are negative correlated with each other on the other hand we can see some are positivly correlated with each other we can see reviews_per month and number of reviews are having a box value of 0.7 so we can assume they are  postively correlated

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
plt.figure(figsize=(10,5))
sns.pairplot(df)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In correlation plot we understand the relation between two variables or data set in terms of number but in pair plot we directly plot the graph between the given variables and see how they are related with each other.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# we can see in above chart we have the graph relation between variables , and by using above graphs we can do the different different anyalysis and we can understand how variables are related with eachother.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# 1. By the analysis of 1st chart we know the count of different types of room available. we can see that no. of shared rooms is very less. therefore shared room listling should be increased to enchance sales.
#
# 2. From the second graph we can figure out inn which neighborhood we have most no. of Airbnb listing and in which neighborhood we have less no. of listing. so by using the business strategies we can distribute Airbnb listing in a proper manner- organised and systematice equal availability  of rooms.
#
# 3 by the analysis of chart 3 we can infer that the shared rooms are available for the most days throughout 365 days. but we know that from chart 1 shared roomms availability is less. so by using our business strategies w ecan increase both the isting and their availabity throughout 365 days.
#
# 4. By the 4th chart, we can see that no. reviews for private rooms are higher. so we can increase their listing and provide them at discounted prices which is another marketing strategy.
#
# 5. By the 5th chart, we can conclude that in neighborhods like staten Island, our properties are avaialable for more time in 365 days. and neighbourhood like brooklyn have Airbnbs that are avialable for lesser duration. Hence we should focus on more properties to be listed in areas that in providing availability for 365 days .
#
# 6 By the 6th chart we can see that customer are more active in the price range of 100--2000 . thats why we will try to provide the best product in the desire price.
#
# 7. From the 7th chart we can see the distribution of different room type in differnt neighbourhood and we can use this analysis for increasing our business sales. We can provide more lsiting for area that have less properties.
#
# 8. BY the 8th chart we can infer which types of rooms are available for minimum 1 night however private rooms are available for hiher amount of one night so we need to make sure all our other products have same or minimum night stays
#
# 9. From the 9th graph we know that in a particular neighbourhood there are certain prices ranges for one night that we can provide so the customer can budget accordingly this way we can coordinate with customers and host to negotiate their prices accordingly.
#
# 10. By 10th chart we can find out many AirBnb are available for in each of the neighborhoods. thats way we can increase our listing neighbourhood that have less lsiting and organize the once that are more in number
#
# 11. From the 11th Graph , we can infer which type of rooms are availabe in different neighbourhoods and which types of rooms should be increse to accomodate more customer in those neighbourhoods.
#
# 12. In the 12th chart we can find price range of particular room type for one night and we can manipulate the prices according to customers reuiqrement
#
# 13. from the 13th graph, we can find out which neighboorhood has pricing high or low for 1 night . however Manhattan has slighty higher pricing than the others. So we can increase the lsiting in manhattan with lesser prices.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# 1. Most of customer prefer price range upto 1000.
# 2. shared room are availabe for most dAYS IN 365 day.
# 3. Manhattan is expensive in comparison to other  neighbourhood.
# 4. Entire home apartment is listed in highest number on Airbnb.
# 5. Manhattan is having highest Airbnb listing Brooklyn comes second queens comes on third
# 6. Customer prefer private rooms in comparison to other type of rooms entire room apartment comes on second , shared rooms comes in third.
# 7. In staten Island rooms are available for large time period in comparison for other neighbourhood.
# 8. Brooklyn have highest number of private rooms and manhattan have highest number of entire home apartment lsitings
# 9. Private rooms are available in large amount where you can stay for minimum one night.
# 10. Entire home apartment is expensive in comparison to other roo type.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
